# %%
import pandas as pd

df=pd.read_csv('creditcard.csv')
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns=None
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Handling missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()

df.Amount=sc.fit_transform(pd.DataFrame(df.Amount))
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# # Handling duplicates

# %%
df=df.drop(['Time'],axis=1)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (275663, 30)

# %% [markdown]
# # Seeing if imbalanced data or not

# %%
df.Class.value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Class', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # Splitting the data into training set and testing set

# %%
x=df.drop('Class',axis=1)
y=df.Class

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20, random_state=42, stratify=y)

# %% [markdown]
# # Undersampling

# %%
from sklearn.utils import resample
new_df = pd.concat([x_train, y_train], axis=1)


normal = new_df[new_df['Class'] == 0]
fraud = new_df[new_df['Class'] == 1]

# %%
normal_new = resample(normal,replace=False,n_samples=len(fraud),random_state=42)

undersampled_train = pd.concat([fraud, normal_new])
undersampled_train = undersampled_train.sample(frac=1, random_state=42)

x_train_under = undersampled_train.drop('Class', axis=1)
y_train_under = undersampled_train['Class']

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression(random_state=42)
log.fit(x_train_under,y_train_under)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred1=log.predict(x_test)

# %% [markdown]
# # Different evaluation metrics

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.9560154535396224

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
precision_score(y_test,y_pred1)
# Out:
# 0.035115722266560255

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9263157894736842

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.06766628219915417

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(random_state=42)
dt.fit(x_train_under,y_train_under)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9158217401556237

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.018023748939779476

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.8947368421052632

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.0353356890459364

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=42)
rf.fit(x_train_under,y_train_under)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred3=rf.predict(x_test)

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.06456456456456457

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9772368635844231

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9052631578947369

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.12053258584442887

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, f1_score

xgb_model = xgb.XGBClassifier(random_state=42, scale_pos_weight=1, eval_metric='logloss')
xgb_model.fit(x_train_under, y_train_under)

y_pred4 = xgb_model.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred4))
print(classification_report(y_test, y_pred4))
# Out:
# [[52550  2488]
#  [    9    86]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98     55038
#            1       0.03      0.91      0.06        95
#
#     accuracy                           0.95     55133
#    macro avg       0.52      0.93      0.52     55133
# weighted avg       1.00      0.95      0.98     55133

# %%
f1_score(y_test,y_pred4)
# Out:
# 0.06444361183964031

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF','XGB'],'F1 scores':[f1_score(y_test,y_pred1)*100,f1_score(y_test,y_pred2)*100,f1_score(y_test,y_pred3)*100,f1_score(y_test,y_pred4)*100]})

# %%
final_data
# Out:
#   Models  F1 scores
# 0     LR   6.766628
# 1     DT   3.533569
# 2     RF  12.053259
# 3    XGB   6.444361

# %%
sns.barplot(x='Models', y='F1 scores', hue='Models', data=final_data, palette='viridis')
# Out:
# <Axes: xlabel='Models', ylabel='F1 scores'>

# %% [markdown]
# # Oversampling

# %%
x=df.drop('Class',axis=1)
y=df.Class

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20, random_state=42, stratify=y)

# %%
from imblearn.over_sampling import SMOTE
x_res,y_res=SMOTE(random_state=42).fit_resample(x_train,y_train)

# %%
y_res.value_counts()
# Out:
# Class
# 0    220152
# 1    220152
# Name: count, dtype: int64

# %% [markdown]
# # Logistic regression

# %%
log=LogisticRegression(random_state=42)
log.fit(x_res,y_res)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred1=log.predict(x_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9744436181597228

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.05727762803234501

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.8947368421052632

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.10766307789740343

# %% [markdown]
# # Decision tree classifier

# %%
dt=DecisionTreeClassifier(random_state=42)
dt.fit(x_res,y_res)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred2=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9974062721056355

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.3695652173913043

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.7157894736842105

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.4874551971326165

# %% [markdown]
# # Random Forest Classifier

# %%
rf=RandomForestClassifier(random_state=42)
rf.fit(x_res,y_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred3=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9993651714943863

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.8333333333333334

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.7894736842105263

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.8108108108108109

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, f1_score

xgb_model = xgb.XGBClassifier(random_state=42, scale_pos_weight=1, eval_metric='logloss')
xgb_model.fit(x_res, y_res)

y_pred4 = xgb_model.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred4))
print(classification_report(y_test, y_pred4))
# Out:
# [[55010    28]
#  [   20    75]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55038
#            1       0.73      0.79      0.76        95
#
#     accuracy                           1.00     55133
#    macro avg       0.86      0.89      0.88     55133
# weighted avg       1.00      1.00      1.00     55133

# %%
f1_score(y_test, y_pred4)
# Out:
# 0.7575757575757576

# %%
final_data=pd.DataFrame({'Models':['LR','DT','RF','XGB'],'F1 scores':[f1_score(y_test,y_pred1)*100,f1_score(y_test,y_pred2)*100,f1_score(y_test,y_pred3)*100,f1_score(y_test,y_pred4)*100]})

# %%
final_data
# Out:
#   Models  F1 scores
# 0     LR  10.766308
# 1     DT  48.745520
# 2     RF  81.081081
# 3    XGB  75.757576

# %%
sns.barplot(x='Models', y='F1 scores', hue='Models', data=final_data, palette='viridis')
# Out:
# <Axes: xlabel='Models', ylabel='F1 scores'>

# %%
import joblib
joblib.dump(rf, "creditcard_fraud_model.pkl")
# Out:
# ['creditcard_fraud_model.pkl']
